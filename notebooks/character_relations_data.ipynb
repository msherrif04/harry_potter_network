# %%
import pandas as pd 
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import matplotlib.pyplot as plt

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 330.3 kB/s eta 0:00:39
#      --------------------------------------- 0.1/12.8 MB 991.0 kB/s eta 0:00:13
#      --------------------------------------- 0.1/12.8 MB 991.0 kB/s eta 0:00:13
#      --------------------------------------- 0.1/12.8 MB 525.1 kB/s eta 0:00:25
#      --------------------------------------- 0.2/12.8 MB 706.2 kB/s eta 0:00:18
#       -------------------------------------- 0.2/12.8 MB 901.1 kB/s eta 0:00:14
#       -------------------------------------- 0.2/12.8 MB 901.1 kB/s eta 0:00:14
#       -------------------------------------- 0.3/12.8 MB 895.6 kB/s eta 0:00:14
#      - -------------------------------------- 0.5/12.8 MB 1.2 MB/s eta 0:00:11
#      - -------------------------------------- 0.6/12.8 MB 1.3 MB/s eta 0:00:10
#      -- ------------------------------------- 0.6/12.8 MB 1.3 MB/s eta 0:00:10
#      -- ------------------------------------- 0.8/12.8 MB 1.5 MB/s eta 0:00:09
#      --- ------------------------------------ 1.0/12.8 MB 1.6 MB/s eta 0:00:08
#      ---- ----------------------------------- 1.3/12.8 MB 2.0 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.5/12.8 MB 2.1 MB/s eta 0:00:06
#      ----- ---------------------------------- 1.9/12.8 MB 2.6 MB/s eta 0:00:05
#      ------- -------------------------------- 2.3/12.8 MB 2.9 MB/s eta 0:00:04
#      ------- -------------------------------- 2.5/12.8 MB 3.0 MB/s eta 0:00:04
#      -------- ------------------------------- 2.7/12.8 MB 3.1 MB/s eta 0:00:04
#      --------- ------------------------------ 3.1/12.8 MB 3.3 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.4/12.8 MB 3.5 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.6/12.8 MB 3.6 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.8 MB 3.7 MB/s eta 0:00:03
#      ------------- -------------------------- 4.2/12.8 MB 3.8 MB/s eta 0:00:03
#      -------------- ------------------------- 4.6/12.8 MB 4.0 MB/s eta 0:00:03
#      --------------- ------------------------ 4.9/12.8 MB 4.1 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.3/12.8 MB 4.2 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.5/12.8 MB 4.3 MB/s eta 0:00:02
#      ------------------ --------------------- 5.8/12.8 MB 4.3 MB/s eta 0:00:02
#      ------------------- -------------------- 6.1/12.8 MB 4.4 MB/s eta 0:00:02
#      ------------------- -------------------- 6.4/12.8 MB 4.4 MB/s eta 0:00:02
#      -------------------- ------------------- 6.7/12.8 MB 4.5 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.1/12.8 MB 4.6 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.4/12.8 MB 4.7 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.5/12.8 MB 4.6 MB/s eta 0:00:02
#      ------------------------ --------------- 7.8/12.8 MB 4.7 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.8 MB 4.7 MB/s eta 0:00:02
#      -------------------------- ------------- 8.5/12.8 MB 4.8 MB/s eta 0:00:01
#      --------------------------- ------------ 8.9/12.8 MB 4.9 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 5.0 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.6/12.8 MB 5.0 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 5.1 MB/s eta 0:00:01
#      -------------------------------- ------- 10.3/12.8 MB 5.2 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.8 MB 6.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.8 MB 6.7 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.8 MB 7.0 MB/s eta 0:00:01
#      ------------------------------------- -- 11.9/12.8 MB 6.9 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 7.0 MB/s eta 0:00:01
#      -------------------------------------- - 12.5/12.8 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 7.0 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 7.0 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from en-core-web-sm==3.5.0) (3.5.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: jinja2 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.3)
# Requirement already satisfied: setuptools in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (65.6.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\sherrif\appdata\roaming\python\python311\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: colorama in c:\users\sherrif\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sherrif\desktop\everything\projects\code\network analysis\harry_potter_network\env\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
#Load the space english language model into a variable
nlp = spacy.load("en_core_web_sm")

# %%
# get all the book files from the data folder

import os
path = '..\data\external'

all_books = [book for book  in os.scandir(path) if '.txt' in book.name]
all_books
# Out:
# [<DirEntry "Book 1 - The Philosopher's Stone.txt">,
#  <DirEntry 'Book 2 - The Chamber of Secrets.txt'>,
#  <DirEntry 'Book 3 - The Prisoner of Azkaban.txt'>,
#  <DirEntry 'Book 4 - The Goblet of Fire.txt'>,
#  <DirEntry 'Book 5 - The Order of the Phoenix.txt'>,
#  <DirEntry 'Book 6 - The Half Blood Prince.txt'>,
#  <DirEntry 'Book 7 - The Deathly Hallows.txt'>]

# %%
book1 = all_books[0]
book1_text = open(book1).read()
book1_doc = nlp(book1_text)

# %%
# visualise the identified entities in book 1

displacy.render(book1_doc[0:1000], style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">/ </br></br></br></br></br>THE BOY WHO
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LIVED
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  </br></br>Mr. and Mrs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dursley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     number four
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Privet Drive
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , </br>were proud to say that they were perfectly normal, </br>thank you very much. They were the last people you’d </br>expect to be involved in anything strange or </br>mysterious, because they just didn’t hold with such </br>nonsense. </br></br>Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dursley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was the director of a firm called </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grunnings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , which made drills. He was a big, beefy </br>man with hardly any neck, although he did have a </br>very large mustache. Mrs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dursley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was thin and </br>blonde and had nearly twice the usual amount of </br>neck, which came in very useful as she spent so </br>much of her time craning over garden fences, spying </br>on the neighbors. The
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dursley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  s had a small son </br>called
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dudley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and in their opinion there was no finer </br>boy anywhere. </br></br>The Dursleys had everything they wanted, but they </br>also had a secret, and their greatest fear was that </br>somebody would discover it. They didn’t think they </br>could bear it if anyone found out about the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Potters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . </br>Mrs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was Mrs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dursley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s sister, but they had
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     n’t
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  </br></br>Page | 2
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harry Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Philosophers Stone - J.K. Rowling
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </br></br></br></br>met for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     several years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ; in fact, Mrs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dursley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  pretended </br>she didn’t have a sister, because her sister and her </br>good-for-nothing husband were as unDursleyish as it </br>was possible to be. The
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dursleys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  shuddered to think </br>what the neighbors would say if the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Potters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  arrived in </br>the street. The Dursleys knew that the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Potters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had a </br>small son, too, but they had never even seen him. </br></br>This boy was another good reason for keeping the </br>
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Potters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</s

# %%
# read characters file

characters_path = r'..\data\interim\ characters.csv'
characters_df = pd.read_csv(characters_path)
characters_df
# Out:
#       Unnamed: 0 letter          character
# 0              0      A        Mrs. Abbott
# 1              1      A      Abbott family
# 2              2      A      Hannah Abbott
# 3              3      A      Abel Treetops
# 4              4      A   Euan Abercrombie
# ...          ...    ...                ...
# 2015        2015      Z     Georgi Zdravko
# 2016        2016      Z             Zograf
# 2017        2017      Z              Zonko
# 2018        2018      Z  Valentina Vázquez
# 2019        2019      Z      Zygmunt Budge
#
# [2020 rows x 3 columns]

# %%
import re

#remove Mr and Mrs from the names
characters_df['character'] = characters_df['character'].str.replace(r'\b(Mr|Mrs)\.?\s', '', regex=True)

#remove all bracketed words from the characters df
characters_df['character'] = characters_df['character'].apply(lambda x: re.sub("[\(].*?[\)]", "", x))

# create a firstname column for the characters
characters_df['firstname'] = characters_df['character'].apply(lambda x: x.split(' ', 1)[0])

# %%
#drop unwanted columns
characters_df.drop(['Unnamed: 0', 'letter'], axis=1, inplace=True)
characters_df
# Out:
#               character  firstname
# 0                Abbott     Abbott
# 1         Abbott family     Abbott
# 2         Hannah Abbott     Hannah
# 3         Abel Treetops       Abel
# 4      Euan Abercrombie       Euan
# ...                 ...        ...
# 2015     Georgi Zdravko     Georgi
# 2016             Zograf     Zograf
# 2017              Zonko      Zonko
# 2018  Valentina Vázquez  Valentina
# 2019      Zygmunt Budge    Zygmunt
#
# [2020 rows x 2 columns]

# %%
# save processed data frame
path= r'..\data\processed\ '
characters_df.to_csv(path+'harry_potter_characters.csv')

# %% [markdown]
# # Get named entities in each sentence

# %%
sentence_entity_df=[]

#loop through sentences and store the named entity list for each sentence
for sentence in book1_doc.sents:
    entity_list = [entity.text for entity in sentence.ents]
    sentence_entity_df.append({'sentence':sentence, 'entities': entity_list})
    
sentence_entity_df=pd.DataFrame(sentence_entity_df)

# %%
sentence_entity_df
# Out:
#                                                sentence
# 0     (/, \n\n\n\n\n, THE, BOY, WHO, LIVED, \n\n, Mr...  \
# 1     (They, were, the, last, people, you, ’d, \n, e...
# 2     (Mr., Dursley, was, the, director, of, a, firm...
# 3     (He, was, a, big, ,, beefy, \n, man, with, har...
# 4     (Mrs., Dursley, was, thin, and, \n, blonde, an...
# ...                                                 ...
# 6337  (“, Hope, you, have, —, er, —, a, good, holida...
# 6338  (Page, |, 347, Harry, Potter, and, the, Philos...
# 6339  (“, They, do, n’t, \n, know, we, ’re, not, all...
# 6340  (I, ’m, \n, going, to, have, a, lot, of, fun, ...
# 6341  (Page, |, 348, Harry, Potter, and, the, Philos...
#
#                                                entities
# 0           [LIVED, Dursley, number four, Privet Drive]
# 1                                                    []
# 2                                  [Dursley, Grunnings]
# 3                                                    []
# 4                                             [Dursley]
# ...                                                 ...
# 6337                                     [Uncle Vernon]
# 6338  [347, Harry Potter, the Philosophers Stone - J...
# 6339                                                 []
# 6340                              [Dudley, this summer]
# 6341  [Harry Potter, the Philosophers Stone - J.K. R...
#
# [6342 rows x 2 columns]

# %%
#little function to filter entity list, taken from Thu Vu

def filter_entity(entity_list, characters_df):
    """_summary_
    this function takes a list of spacy generated entities and the character dataframe and returns only entities that are characters in the dataframe

    Args:
        entity_list (list): list of entities generated by spacy nlp
        characters_df (dataframe): dataframe of characters from scraped from the harry potter website
    """
    return [entity for entity in entity_list
            if entity in list(characters_df.character)
            or entity in list(characters_df.firstname)]

# %%
#test
filter_entity(['Harry','boy','waakye'], characters_df)
# Out:
# ['Harry']

# %%
sentence_entity_df['character_entities'] = sentence_entity_df['entities'].apply(lambda x: filter_entity(x, characters_df))

#remove sentences without named entities
sentence_entity_df_filtered = sentence_entity_df[sentence_entity_df['character_entities'].map(len)>0]
sentence_entity_df_filtered.head()
# Out:
#                                             sentence
# 0  (/, \n\n\n\n\n, THE, BOY, WHO, LIVED, \n\n, Mr...  \
# 2  (Mr., Dursley, was, the, director, of, a, firm...
# 4  (Mrs., Dursley, was, thin, and, \n, blonde, an...
# 5  (The, Dursley, s, had, a, small, son, \n, call...
# 8  (Mrs., Potter, was, Mrs., Dursley, ’s, sister,...
#
#                                             entities
# 0        [LIVED, Dursley, number four, Privet Drive]  \
# 2                               [Dursley, Grunnings]
# 4                                          [Dursley]
# 5                                  [Dursley, Dudley]
# 8  [Potter, Dursley, n’t, Harry Potter, the Philo...
#
#                          character_entities
# 0                                 [Dursley]
# 2                                 [Dursley]
# 4                                 [Dursley]
# 5                         [Dursley, Dudley]
# 8  [Potter, Dursley, Harry Potter, Dursley]

# %%
# Take only first name of characters
sentence_entity_df_filtered['character_entities'] = sentence_entity_df_filtered['character_entities'].apply(lambda x: [item.split()[0] 
                                                                                                               for item in x])
# Out:
# C:\Users\Sherrif\AppData\Local\Temp\ipykernel_8060\1625169097.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentence_entity_df_filtered['character_entities'] = sentence_entity_df_filtered['character_entities'].apply(lambda x: [item.split()[0]

# %%
#potter = harry
sentence_entity_df_filtered['character_entities'] = sentence_entity_df_filtered['character_entities'].apply(lambda x: [item.replace('Potter', 'Harry') for item in x])
sentence_entity_df_filtered
# Out:
# C:\Users\Sherrif\AppData\Local\Temp\ipykernel_8060\1896469444.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentence_entity_df_filtered['character_entities'] = sentence_entity_df_filtered['character_entities'].apply(lambda x: [item.replace('Potter', 'Harry') for item in x])
#                                                sentence
# 0     (/, \n\n\n\n\n, THE, BOY, WHO, LIVED, \n\n, Mr...  \
# 2     (Mr., Dursley, was, the, director, of, a, firm...
# 4     (Mrs., Dursley, was, thin, and, \n, blonde, an...
# 5     (The, Dursley, s, had, a, small, son, \n, call...
# 8     (Mrs., Potter, was, Mrs., Dursley, ’s, sister,...
# ...                                                 ...
# 6331  (“, You, must, be, Harry, ’s, family, !, ”, sa...
# 6335  (Harry, hung, back, for, a, last, word, with, ...
# 6338  (Page, |, 347, Harry, Potter, and, the, Philos...
# 6340  (I, ’m, \n, going, to, have, a, lot, of, fun, ...
# 6341  (Page, |, 348, Harry, Potter, and, the, Philos...
#
#                                                entities
# 0           [LIVED, Dursley, number four, Privet Drive]  \
# 2                                  [Dursley, Grunnings]
# 4                                             [Dursley]
# 5                                     [Dursley, Dudley]
# 8     [Potter, Dursley, n’t, Harry Potter, the Philo...
# ...                                                 ...
# 6331                                   [Harry, Weasley]
# 6335                                  [Harry hung, Ron]
# 6338  [347, Harry Potter, the Philosophers Stone - J...
# 6340                              [Dudley, this summer]
# 6341  [Harry Potter, the Philosophers Stone - J.K. R...
#
#                     character_entities
# 0                            [Dursley]
# 2                            [Dursley]
# 4                            [Dursley]
# 5                    [Dursley, Dudley]
# 8     [Harry, Dursley, Harry, Dursley]
# ...                                ...
# 6331                  [Harry, Weasley]
# 6335                             [Ron]
# 6338                    [Harry, Harry]
# 6340                          [Dudley]
# 6341                           [Harry]
#
# [2824 rows x 3 columns]

# %% [markdown]
# ## Create relationships between characters

# %%
window_size = 5
character_relationships =[]

for i in range(sentence_entity_df_filtered.index[-1]):
    end_i = min(i+5, sentence_entity_df_filtered.index[-1])
    char_list = sum((sentence_entity_df_filtered.loc[i:end_i].character_entities),[])
    
    #remove duplicated characters that are next to each other
    char_unique = [char_list[i] for i in range(len(char_list))
                    if (i==0) or char_list[i] != char_list[1-i]]
    
    #create a source and target character for each interaction in the window
    if len(char_unique) > 1:
        for index, source in enumerate(char_unique[:-1]):
            target = char_unique[index+1]
            character_relationships.append({'source': source, 'target': target})

# %%
character_relationships_df = pd.DataFrame(character_relationships)
character_relationships_df
# Out:
#         source   target
# 0      Dursley  Dursley
# 1      Dursley   Dudley
# 2      Dursley  Dursley
# 3      Dursley   Dudley
# 4      Dursley  Dursley
# ...        ...      ...
# 11676   Dudley    Harry
# 11677    Harry   Dudley
# 11678   Dudley    Harry
# 11679   Dudley    Harry
# 11680   Dudley    Harry
#
# [11681 rows x 2 columns]

# %%
#some duplicates still remain so remove rows where values for source and target are the same
drop_indexes = character_relationships_df[character_relationships_df['source'] == character_relationships_df['target']].index
character_relationships_df.drop(drop_indexes, inplace=True)

# %%
character_relationships_df
# Out:
#         source   target
# 1      Dursley   Dudley
# 3      Dursley   Dudley
# 5      Dursley   Dudley
# 6      Dursley   Dudley
# 7       Dudley  Dursley
# ...        ...      ...
# 11676   Dudley    Harry
# 11677    Harry   Dudley
# 11678   Dudley    Harry
# 11679   Dudley    Harry
# 11680   Dudley    Harry
#
# [10924 rows x 2 columns]

# %%
#sort rows column wise to fix reverse interactions eg a->b = b->a

character_relationships_df = pd.DataFrame(np.sort(character_relationships_df.values, axis=1), columns = character_relationships_df.columns)
character_relationships_df
# Out:
#        source   target
# 0      Dudley  Dursley
# 1      Dudley  Dursley
# 2      Dudley  Dursley
# 3      Dudley  Dursley
# 4      Dudley  Dursley
# ...       ...      ...
# 10919  Dudley    Harry
# 10920  Dudley    Harry
# 10921  Dudley    Harry
# 10922  Dudley    Harry
# 10923  Dudley    Harry
#
# [10924 rows x 2 columns]

# %%
#aggregate interactions for each character pair and create a weight column
character_relationships_df['value']=1
character_relationships_df = character_relationships_df.groupby(['source', 'target'], sort=False, as_index=False).sum()
character_relationships_df
# Out:
#       source   target  value
# 0     Dudley  Dursley     55
# 1     Dudley    Harry    496
# 2    Dursley    Harry     62
# 3     Dudley   second     22
# 4    Dursley   second      6
# ..       ...      ...    ...
# 519     Fred   Hagrid      5
# 520     Fred  Neville      1
# 521    Ginny      Ron      6
# 522    Ginny  Weasley      5
# 523   Dudley  Weasley      1
#
# [524 rows x 3 columns]

# %%
path = r'..\data\processed\ '
character_relationships_df.to_csv(path+'character_relationships.csv')
